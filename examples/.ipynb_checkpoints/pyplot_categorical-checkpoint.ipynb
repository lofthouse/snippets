# %%
import pandas as pd
import matplotlib.pyplot as plt
a = pd.DataFrame( { "TimeStamp": ['2020-01-01 01:01:01', '2020-01-01 01:01:02', '2020-01-01 01:01:03', '2020-01-01 01:01:04', '2020-01-01 01:01:05'], "Data":[None,"foo","bar","bar","foo"] } )
a[ "TimeStamp" ] = pd.to_datetime(a[ "TimeStamp" ])
fig, ax = plt.subplots()
a.loc[ 0,"Data" ] = ""
ax.plot( a["TimeStamp"], a["Data"], label="FooBar" )
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
a = pd.DataFrame( { "TimeStamp": ['2020-01-01 01:01:01', '2020-01-01 01:01:02', '2020-01-01 01:01:03', '2020-01-01 01:01:04', '2020-01-01 01:01:05'], "Data":["foo","bar","bar","foo",None] } )
a[ "TimeStamp" ] = pd.to_datetime(a[ "TimeStamp" ])
fig, ax = plt.subplots()
ax.plot( a["TimeStamp"], a["Data"], label="FooBar" )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-e6891792b7f9> in <module>
#       4 a[ "TimeStamp" ] = pd.to_datetime(a[ "TimeStamp" ])
#       5 fig, ax = plt.subplots()
# ----> 6 ax.plot( a["TimeStamp"], a["Data"], label="FooBar" )
#       7 plt.show()
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# ...
